# %% [markdown]
# #Modeling Spatial and Temporal Dependencies ofUser Mobility in Wireless Mobile Networks : PAPER IMPLIMENTATION

# %% [markdown]
# I have considered IIT Jodhpur scenario for the implimentation of this paper.
#
# There are basically 4 communities
#
#
# *   LHB +Hostels+Dinner Hall
# *   Health Center
# *   Sports Complex
# *   Electrical Department
#
# For every time slot, the community varies, thus size gets varied. The community plot is provided below
#
# The dataset contains the scenario for 2 days, aorund 30 hrs of time period. The dataset contains the location of the user, the cell ID to which the user is connected at particular location, the user ID as unique identification. There are 10 different users I have considered in the senario. e.g. 'BK73'
#
# Spatial and temporal plots are also provided below.

# %% [markdown]
# ##Location Plot : IIT Jodhpur

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/My Drive/Tejas IIT Jodhpur/SEMESTER 2/MLC/MLCW_Assignment 1/UMD_IITJ.csv',header=1)
y=np.asarray(df[['Location','Lat','Long']])
val=[]
for i in range(len(y)):
  if list(y[i,:]) not in val:
    val.append(list(y[i,:])) 
    
val=np.asarray(val)
BBox = ((df.Long.min(),   df.Long.max(),      
         df.Lat.min(), df.Lat.max()))
ruh_m = plt.imread('/content/drive/My Drive/Tejas IIT Jodhpur/SEMESTER 2/MLC/MLCW_Assignment 1/iitj map.png')
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df.Long, df.Lat, zorder=1, alpha= 0.2, c='red', s=50,marker='o')
#ax.plot(np.asarray(c)[:,1],np.asarray(c)[:,0],c='black')
ax.set_title('Plotting Spatial Data on IIT Jodhpur Map')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
plt.savefig('main_area.png')

# %% [markdown]
# ##DataSet

# %%
df.head(10)
# Out:
#   Date and Starting Time  ... Device ID
# 0     2020-11-21 0:22:01  ...      BK83
# 1     2020-11-21 0:22:02  ...      BK83
# 2     2020-11-21 0:22:03  ...      BK83
# 3     2020-11-21 0:22:04  ...      BK83
# 4     2020-11-21 0:22:05  ...      BK82
# 5     2020-11-21 0:22:06  ...      BK82
# 6     2020-11-21 0:22:07  ...      BK82
# 7     2020-11-21 0:22:08  ...      BK82
# 8     2020-11-21 0:22:09  ...      BK79
# 9     2020-11-21 0:22:10  ...      BK79
#
# [10 rows x 9 columns]

# %%
users=np.unique(np.asarray(df['Device ID']))
i=0
maping=[]
for j in range(len(users)):
  for i in range(len(df)):
    if users[j]==df['Device ID'][i]:
      maping.append(users[j])
      maping.append(df.Lat[i])
      maping.append(df.Long[i])
      maping.append(df['Duration of connection'][i])
  j+=1
G=pd.DataFrame(np.asarray(maping).reshape((-1,4)))
g=np.asarray(G)
g1=g[:,1:-1].astype(float)
B=[]
for i in range(len(final1)):
  B.append(np.sort(final1[i][:,-1])[len(final1[i])-2:])

# %% [markdown]
# ##ALL Users: Spatial Mobility

# %%
final1=[]
j=0
for j in range(len(users)):
  c1=[]
  for i in  range(len(g)):
    if users[j]==g[i,0]:
      c1.append(g[i,:])
  final1.append(np.asarray(c1))

final=[]
j=0
for j in range(len(users)):
  c=[]
  for i in  range(len(g)):
    if users[j]==g[i,0]:
      c.append(g1[i,:])
  final.append(c)
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(df.Long, df.Lat, zorder=1, alpha= 0.2, c='red', s=50,marker='o')
ax.plot(g1[:,1],g1[:,0],c='black')
ax.set_title('Plotting Spatial Data on IIT Jodhpur Map for all users')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
table_labels=['User','Latitude','Longitude','Duration']
#ax.table(g[:,:],colLabels=table_labels)
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
plt.savefig('1.png')

# %% [markdown]
# ##User Wise Spatial Mobility

# %%
k=0
for i in range(len(users)): 
  fig, ax = plt.subplots(figsize = (10,8.5))
  ax.scatter(df.Long, df.Lat, zorder=1, alpha= 0.2, c='red', s=50,marker='o')
  ax.plot(np.asarray((np.asarray(final)[i]))[:,1],np.asarray((np.asarray(final)[i]))[:,0],c='black')
  ax.set_title('Plotting Spatial Data on IIT Jodhpur Map, user: {}'.format(users[i]))
  ax.set_xlim(BBox[0],BBox[1])
  ax.set_ylim(BBox[2],BBox[3])
  ax.set_xlabel('Longitude')
  ax.set_ylabel('Latitude')
  ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %% [markdown]
# ##User Wise Temporal and Spatial Information

# %%
import plotly.graph_objects as go
for i in range(len(users)):
  fig = go.Figure(data=[go.Table(header=dict(values=['User','Latitude','Longitude','Duration']),
                  cells=dict(values=[final1[i][:,0],final1[i][:,1],final1[i][:,2],final1[i][:,3] ]))
                      ])
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b240021a-4731-4122-9400-acd6ff996cc7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b240021a-4731-4122-9400-acd6ff996cc7")) {
#                     Plotly.newPlot(
#                         'b240021a-4731-4122-9400-acd6ff996cc7',
# ...

# %%
import cv2 
     
image = cv2.imread('1.png')
fig, ax= plt.subplots(figsize = (10,8.5))
window_name = 'Image'
start_point = (75,400) 
end_point = (150,275) 
color  = (0,0,0) 
c1=(255,0,0) 
thickness = 2
ax.set_title('COMMUNITY WISE SPLIT: Time Slot 1')
image = cv2.putText(image, 'Community 1', (75, 255) , cv2.FONT_HERSHEY_SIMPLEX ,0.5, (0,0,0), 1, cv2.LINE_AA) 
image = cv2.rectangle(image, start_point, end_point, c1, thickness) 
image = cv2.putText(image, 'Community 2', (300, 315) , cv2.FONT_HERSHEY_SIMPLEX ,0.5, (0,0,0), 1, cv2.LINE_AA) 
image = cv2.rectangle(image,(200,325), (400,450), (0,255,0), thickness) 
image = cv2.putText(image, 'Community 3', (450, 185) , cv2.FONT_HERSHEY_SIMPLEX ,0.5, (0,0,0), 1, cv2.LINE_AA) 
image = cv2.rectangle(image,(500,200), (550,300), (0,0,0), thickness) 
image = cv2.putText(image, 'Community 4', (250, 30) , cv2.FONT_HERSHEY_SIMPLEX ,0.5, (0,0,0), 1, cv2.LINE_AA) 
image = cv2.rectangle(image,(270,55), (355,100), (0,0,255), thickness) 
ax.imshow(image)

# %%
import cv2 
     
image = cv2.imread('1.png')
fig, ax= plt.subplots(figsize = (10,8.5))
window_name = 'Image'
start_point = (75,400) 
end_point = (150,275) 
color  = (0,0,0) 
c1=(255,0,0) 
thickness = 2
ax.set_title('COMMUNITY WISE SPLIT: Time Slot 2')
image = cv2.putText(image, 'Community 1', (75, 300) , cv2.FONT_HERSHEY_SIMPLEX ,0.5, (0,0,0), 2, cv2.LINE_AA) 
image = cv2.rectangle(image, (75,350), (100,400), c1, thickness) 
image = cv2.putText(image, 'Community 2', (300, 315) , cv2.FONT_HERSHEY_SIMPLEX ,0.5, (0,0,0), 2, cv2.LINE_AA) 
image = cv2.rectangle(image,(220,325), (420,450), (0,255,0), thickness) 
image = cv2.putText(image, 'Community 3', (450, 185) , cv2.FONT_HERSHEY_SIMPLEX ,0.5, (0,0,0), 2, cv2.LINE_AA) 
image = cv2.rectangle(image,(510,230), (530,270), (0,0,0), thickness) 
image = cv2.putText(image, 'Community 4', (250, 20) , cv2.FONT_HERSHEY_SIMPLEX ,0.5, (0,0,0), 2, cv2.LINE_AA) 
image = cv2.rectangle(image,(260,55), (350,100), (0,0,255), thickness) 
ax.imshow(image)

# %% [markdown]
# ##Skewed Location visiting preferences

# %%
i=0
mapping=[]
for j in range(len(users)):
  for i in range(len(df)):
    if users[j]==df['Device ID'][i]:
      mapping.append(users[j])
      mapping.append(df.Lat[i])
      mapping.append(df.Long[i])
      mapping.append(df.Location[i])
      mapping.append(df['Duration of connection'][i])
  j+=1
G2=pd.DataFrame(np.asarray(mapping).reshape((-1,5)))
g2=np.asarray(G2)
final2=[]
j=0
for j in range(len(users)):
  c2=[]
  for i in  range(len(g2)):
    if users[j]==g2[i,0]:
      c2.append(g2[i,:])
  final2.append(np.asarray(c2))
jal=[]
for k in range(len(users)):
  for i in range((len(final2[k]))):
    if final2[k][i,-1]==B[k][0] or final2[k][i,-1]==B[k][1]:
      jal.append(final2[k][i,:])
t=(np.asarray(jal)[:,[0,3]])
fig = go.Figure(data=[go.Table(header=dict(values=['User','Location']),
                  cells=dict(values=[t[:,0],t[:,1] ]))
                      ])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a56be959-a2eb-43f9-ae48-f52c9cae427d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a56be959-a2eb-43f9-ae48-f52c9cae427d")) {
#                     Plotly.newPlot(
#                         'a56be959-a2eb-43f9-ae48-f52c9cae427d',
# ...
